# %% [markdown]
# Sources:
#
# https://blog.featurelabs.com/predicting-credit-card-fraud/
#
# https://blog.featurelabs.com/deep-feature-synthesis/

# %% [markdown]
# # Load the data

# %%
import pandas as pd
import numpy as np
import featuretools as ft

# %%
train = pd.read_csv('train.csv', sep='|')
test = pd.read_csv('test.csv', sep='|')

# %%
train.head(1)
# Out:
#    trustLevel  totalScanTimeInSeconds  grandTotal  lineItemVoids  \
# 0           5                    1054        54.7              7
#
#    scansWithoutRegistration  quantityModifications  scannedLineItemsPerSecond  \
# 0                         0                      3                   0.027514
#
#    valuePerSecond  lineItemVoidsPerPosition  fraud
# 0        0.051898                  0.241379      0

# %%
train['scannedLineItemsTotal'] = train['scannedLineItemsPerSecond'] * train['totalScanTimeInSeconds']

# %%
train_new = train
"""
7 main features:
    trustLevel
    totalScanTimeInSeconds
    grandTotal
    lineItemVoids
    scansWithoutRegistration
    quantityModifications
    scannedLineItemsTotal
"""
# Out:
# '\n7 main features:\n    trustLevel\n    totalScanTimeInSeconds\n    grandTotal\n    lineItemVoids\n    scansWithoutRegistration\n    quantityModifications\n    scannedLineItemsTotal\n'

# %%
train_new.drop(columns=['fraud','valuePerSecond','scannedLineItemsPerSecond','lineItemVoidsPerPosition'], inplace=True)
train_new.head()
# Out:
#    trustLevel  totalScanTimeInSeconds  grandTotal  lineItemVoids  \
# 0           5                    1054       54.70              7
# 1           3                     108       27.36              5
# 2           3                    1516       62.16              3
# 3           6                    1791       92.31              8
# 4           5                     430       81.53              3
#
#    scansWithoutRegistration  quantityModifications  scannedLineItemsTotal
# 0                         0                      3                   29.0
# 1                         2                      4                   14.0
# 2                        10                      5                   13.0
# 3                         4                      4                   29.0
# 4                         7                      2                   27.0

# %% [markdown]
# # Prepare the Data

# %% [markdown]
# Within featuretools there is a standard format for representing data and build features, which is a entity set. A EntitySet stores information about entities (database table), variables (columns in database tables), relationships, and the data itself.

# %%
es = ft.EntitySet("train")

# %%
from featuretools import variable_types as vtypes

es.entity_from_dataframe(entity_id="train",
                         dataframe=train_new,
                         index="id",
                         time_index='totalScanTimeInSeconds')
# Out:
# 2019-05-01 15:08:10,421 featuretools.entityset - WARNING    index id not found in dataframe, creating new integer column
# Entityset: train
#   Entities:
#     train [Rows: 1879, Columns: 8]
#   Relationships:
#     No relationships

# %%
es['train'].df.head()
# Out:
#         id  trustLevel  totalScanTimeInSeconds  grandTotal  lineItemVoids  \
# 173    173           6                       2       75.74              6
# 1715  1715           1                       2       34.07              5
# 1423  1423           6                       3        7.68              2
# 1835  1835           3                       3       64.94              3
# 1154  1154           5                       4       53.65             11
#
#       scansWithoutRegistration  quantityModifications  scannedLineItemsTotal
# 173                          1                      1                    8.0
# 1715                         9                      4                    1.0
# 1423                         3                      0                   20.0
# 1835                         4                      3                   14.0
# 1154                         5                      4                    6.0

# %% [markdown]
# # Feature Primitives

# %% [markdown]
# A feature primitive is an operation applied to a table or a set of tables to create a feature. Feature primitives fall into two categories:
#
# Aggregation: function that groups together children for each parent feature and calculates a statistic such as mean, min, max, or standard deviation across the children.
#
# Transformation: an operation applied to one or more columns in a single table.
#
# A list of the available features primitives in featuretools can be viewed below.

# %%
primitives = ft.list_primitives()
pd.options.display.max_colwidth = 100

primitives[primitives['type'] == 'aggregation'].head(10)
# Out:
#               name         type  \
# 0     percent_true  aggregation
# 1             mean  aggregation
# 2             last  aggregation
# 3         num_true  aggregation
# 4              sum  aggregation
# 5              std  aggregation
# 6       num_unique  aggregation
# 7             skew  aggregation
# 8              max  aggregation
# 9  time_since_last  aggregation
#
#                                                                        description
# 0                                         Determines the percent of `True` values.
# 1                                       Computes the average for a list of values.
# 2                                             Determines the last value in a list.
# 3                                              Counts the number of `True` values.
# 4                                   Calculates the total addition, ignoring `NaN`.
# 5              Computes the dispersion relative to the mean value, ignoring `NaN`.
# 6                 Determines the number of distinct values, ignoring `NaN` values.
# 7  Computes the extent to which a distribution differs from a normal distribution.
# 8                             Calculates the highest value, ignoring `NaN` values.
# 9                Calculates the time elapsed since the last datetime (in seconds).

# %%
primitives[primitives['type'] == 'transform']
# Out:
#                                name       type  \
# 20                        not_equal  transform
# 21                             week  transform
# 22                          cum_sum  transform
# 23                   divide_numeric  transform
# 24                        longitude  transform
# 25                              and  transform
# 26                            equal  transform
# 27                             year  transform
# 28                           second  transform
# 29                     greater_than  transform
# 30                 multiply_numeric  transform
# 31                       percentile  transform
# 32               less_than_equal_to  transform
# 33            modulo_numeric_scalar  transform
# 34                       time_since  transform
# 35                              day  transform
# 36          subtract_numeric_scalar  transform
# 37                           negate  transform
# 38                divide_by_feature  transform
# 39                        less_than  transform
# 40                   num_characters  transform
# 41              time_since_previous  transform
# 42               add_numeric_scalar  transform
# 43                             isin  transform
# 44                         absolute  transform
# 45            greater_than_equal_to  transform
# 46                       is_weekend  transform
# 47                          cum_min  transform
# 48                 not_equal_scalar  transform
# 49                            month  transform
# 50                        cum_count  transform
# 51                        haversine  transform
# 52                     equal_scalar  transform
# 53                               or  transform
# 54                           minute  transform
# 55          multiply_numeric_scalar  transform
# 56                         latitude  transform
# 57        less_than_equal_to_scalar  transform
# 58                modulo_by_feature  transform
# 59                             hour  transform
# 60  scalar_subtract_numeric_feature  transform
# 61                              not  transform
# 62                 less_than_scalar  transform
# 63                   modulo_numeric  transform
# 64                        num_words  transform
# 65                 subtract_numeric  transform
# 66                             diff  transform
# 67            divide_numeric_scalar  transform
# 68     greater_than_equal_to_scalar  transform
# 69                          weekday  transform
# 70                          cum_max  transform
# 71                      add_numeric  transform
# 72                       days_since  transform
# 73              greater_than_scalar  transform
# 74                          is_null  transform
# 75                         cum_mean  transform
#
#                                                                     description
# 20              Determines if values in one list are not equal to another list.
# 21                             Determines the week of the year from a datetime.
# 22                                               Calculates the cumulative sum.
# 23                                          Element-wise division of two lists.
# 24                  Returns the second tuple value in a list of LatLong tuples.
# 25                                       Element-wise logical AND of two lists.
# 26                  Determines if values in one list are equal to another list.
# 27                                     Determines the year value of a datetime.
# 28                                  Determines the seconds value of a datetime.
# 29              Determines if values in one list are greater than another list.
# 30                                    Element-wise multiplication of two lists.
# 31                     Determines the percentile rank for each value in a list.
# 32     Determines if values in one list are less than or equal to another list.
# 33                   Return the modulo of each element in the list by a scalar.
# 34  Calculates time in nanoseconds from a value to a specified cutoff datetime.
# 35                             Determines the day of the month from a datetime.
# 36                             Subtract a scalar from each element in the list.
# 37                                                     Negates a numeric value.
# 38                                   Divide a scalar by each value in the list.
# 39                 Determines if values in one list are less than another list.
# 40                             Calculates the number of characters in a string.
# 41         Compute the time in seconds since the previous instance of an entry.
# 42                                      Add a scalar to each value in the list.
# 43                    Determines whether a value is present in a provided list.
# 44                                     Computes the absolute value of a number.
# 45  Determines if values in one list are greater than or equal to another list.
# 46                                     Determines if a date falls on a weekend.
# 47                                           Calculates the cumulative minimum.
# 48              Determines if values in a list are not equal to a given scalar.
# 49                                    Determines the month value of a datetime.
# 50                                             Calculates the cumulative count.
# 51            Calculates the approximate haversine distance between two LatLong
# 52                  Determines if values in a list are equal to a given scalar.
# 53                                        Element-wise logical OR of two lists.
# 54                                  Determines the minutes value of a datetime.
# 55                               Multiply each element in the list by a scalar.
# 56                   Returns the first tuple value in a list of LatLong tuples.
# 57               Determines if values are less than or equal to a given scalar.
# 58                   Return the modulo of a scalar by each element in the list.
# 59                                     Determines the hour value of a datetime.
# 60                         Subtract each value in the list from a given scalar.
# 61                                                     Negates a boolean value.
# 62                           Determines if values are less than a given scalar.
# 63                                            Element-wise modulo of two lists.
# 64           Determines the number of words in a string by counting the spaces.
# 65                                       Element-wise subtraction of two lists.
# 66                   Compute the difference between the value in a list and the
# 67                                 Divide each element in the list by a scalar.
# 68            Determines if values are greater than or equal to a given scalar.
# 69                              Determines the day of the week from a datetime.
# 70                                           Calculates the cumulative maximum.
# 71                                          Element-wise addition of two lists.
# 72          Calculates the number of days from a value to a specified datetime.
# 73                        Determines if values are greater than a given scalar.
# 74                                               Determines if a value is null.
# 75                                              Calculates the cumulative mean.

# %% [markdown]
# # Deep Feature Synthesis

# %% [markdown]
# DFS stacks feature primitives to form features with a "depth" equal to the number of primitives.

# %%
# use mutiply, add, divide, substract
default_trans_primitives =  ["multiply_numeric", "add_numeric", "divide_numeric", "subtract_numeric"]

# DFS with specified primitives
feature_matrix, features = ft.dfs(entityset = es, target_entity = 'train',
                       trans_primitives = default_trans_primitives,
                       where_primitives = [], seed_features = [],
                       n_jobs = 1, verbose = 1,
                       max_depth = 1, features_only=False)  #set max_depth = 1
# Out:
# Built 112 features
# Elapsed: 00:02 | Remaining: 00:00 | Progress: 100%|██████████| Calculated: 11/11 chunks

# %%
features
# Out:
# [<Feature: trustLevel>,
#  <Feature: totalScanTimeInSeconds>,
#  <Feature: grandTotal>,
#  <Feature: lineItemVoids>,
#  <Feature: scansWithoutRegistration>,
#  <Feature: quantityModifications>,
#  <Feature: scannedLineItemsTotal>,
#  <Feature: quantityModifications * scannedLineItemsTotal>,
#  <Feature: lineItemVoids * totalScanTimeInSeconds>,
#  <Feature: scannedLineItemsTotal * trustLevel>,
#  <Feature: grandTotal * quantityModifications>,
#  <Feature: lineItemVoids * scannedLineItemsTotal>,
#  <Feature: quantityModifications * totalScanTimeInSeconds>,
#  <Feature: scansWithoutRegistration * totalScanTimeInSeconds>,
#  <Feature: scansWithoutRegistration * trustLevel>,
#  <Feature: quantityModifications * trustLevel>,
#  <Feature: lineItemVoids * scansWithoutRegistration>,
#  <Feature: lineItemVoids * quantityModifications>,
#  <Feature: grandTotal * scannedLineItemsTotal>,
#  <Feature: scannedLineItemsTotal * totalScanTimeInSeconds>,
#  <Feature: grandTotal * scansWithoutRegistration>,
#  <Feature: lineItemVoids * trustLevel>,
#  <Feature: grandTotal * lineItemVoids>,
#  <Feature: scannedLineItemsTotal * scansWithoutRegistration>,
#  <Feature: grandTotal * totalScanTimeInSeconds>,
#  <Feature: quantityModifications * scansWithoutRegistration>,
#  <Feature: totalScanTimeInSeconds * trustLevel>,
#  <Feature: grandTotal * trustLevel>,
#  <Feature: quantityModifications + scannedLineItemsTotal>,
#  <Feature: lineItemVoids + totalScanTimeInSeconds>,
#  <Feature: scannedLineItemsTotal + trustLevel>,
#  <Feature: grandTotal + quantityModifications>,
#  <Feature: lineItemVoids + scannedLineItemsTotal>,
#  <Feature: quantityModifications + totalScanTimeInSeconds>,
#  <Feature: scansWithoutRegistration + totalScanTimeInSeconds>,
#  <Feature: scansWithoutRegistration + trustLevel>,
#  <Feature: quantityModifications + trustLevel>,
#  <Feature: lineItemVoids + scansWithoutRegistration>,
#  <Feature: lineItemVoids + quantityModifications>,
#  <Feature: grandTotal + scannedLineItemsTotal>,
#  <Feature: scannedLineItemsTotal + totalScanTimeInSeconds>,
#  <Feature: grandTotal + scansWithoutRegistration>,
#  <Feature: lineItemVoids + trustLevel>,
#  <Feature: grandTotal + lineItemVoids>,
#  <Feature: scannedLineItemsTotal + scansWithoutRegistration>,
#  <Feature: grandTotal + totalScanTimeInSeconds>,
#  <Feature: quantityModifications + scansWithoutRegistration>,
#  <Feature: totalScanTimeInSeconds + trustLevel>,
#  <Feature: grandTotal + trustLevel>,
#  <Feature: quantityModifications / scannedLineItemsTotal>,
#  <Feature: lineItemVoids / totalScanTimeInSeconds>,
#  <Feature: scannedLineItemsTotal / quantityModifications>,
#  <Feature: scannedLineItemsTotal / trustLevel>,
#  <Feature: quantityModifications / lineItemVoids>,
#  <Feature: trustLevel / lineItemVoids>,
#  <Feature: totalScanTimeInSeconds / grandTotal>,
#  <Feature: grandTotal / quantityModifications>,
#  <Feature: totalScanTimeInSeconds / scansWithoutRegistration>,
#  <Feature: trustLevel / quantityModifications>,
#  <Feature: lineItemVoids / scannedLineItemsTotal>,
#  <Feature: totalScanTimeInSeconds / quantityModifications>,
#  <Feature: quantityModifications / totalScanTimeInSeconds>,
#  <Feature: scansWithoutRegistration / totalScanTimeInSeconds>,
#  <Feature: scansWithoutRegistration / trustLevel>,
#  <Feature: scannedLineItemsTotal / lineItemVoids>,
#  <Feature: quantityModifications / trustLevel>,
#  <Feature: lineItemVoids / scansWithoutRegistration>,
#  <Feature: totalScanTimeInSeconds / scannedLineItemsTotal>,
#  <Feature: lineItemVoids / quantityModifications>,
#  <Feature: trustLevel / scannedLineItemsTotal>,
#  <Feature: grandTotal / scannedLineItemsTotal>,
#  <Feature: scannedLineItemsTotal / totalScanTimeInSeconds>,
#  <Feature: grandTotal / scansWithoutRegistration>,
#  <Feature: scansWithoutRegistration / lineItemVoids>,
#  <Feature: totalScanTimeInSeconds / lineItemVoids>,
#  <Feature: lineItemVoids / trustLevel>,
#  <Feature: grandTotal / lineItemVoids>,
#  <Feature: quantityModifications / grandTotal>,
#  <Feature: scannedLineItemsTotal / scansWithoutRegistration>,
#  <Feature: trustLevel / grandTotal>,
#  <Feature: trustLevel / scansWithoutRegistration>,
#  <Feature: grandTotal / totalScanTimeInSeconds>,
#  <Feature: quantityModifications / scansWithoutRegistration>,
#  <Feature: trustLevel / totalScanTimeInSeconds>,
#  <Feature: scannedLineItemsTotal / grandTotal>,
#  <Feature: scansWithoutRegistration / scannedLineItemsTotal>,
#  <Feature: scansWithoutRegistration / quantityModifications>,
#  <Feature: totalScanTimeInSeconds / trustLevel>,
#  <Feature: grandTotal / trustLevel>,
#  <Feature: lineItemVoids / grandTotal>,
#  <Feature: scansWithoutRegistration / grandTotal>,
#  <Feature: quantityModifications - scannedLineItemsTotal>,
#  <Feature: lineItemVoids - totalScanTimeInSeconds>,
#  <Feature: scannedLineItemsTotal - trustLevel>,
#  <Feature: grandTotal - quantityModifications>,
#  <Feature: lineItemVoids - scannedLineItemsTotal>,
#  <Feature: quantityModifications - totalScanTimeInSeconds>,
#  <Feature: scansWithoutRegistration - totalScanTimeInSeconds>,
#  <Feature: scansWithoutRegistration - trustLevel>,
#  <Feature: quantityModifications - trustLevel>,
#  <Feature: lineItemVoids - scansWithoutRegistration>,
#  <Feature: lineItemVoids - quantityModifications>,
#  <Feature: grandTotal - scannedLineItemsTotal>,
#  <Feature: scannedLineItemsTotal - totalScanTimeInSeconds>,
#  <Feature: grandTotal - scansWithoutRegistration>,
#  <Feature: lineItemVoids - trustLevel>,
#  <Feature: grandTotal - lineItemVoids>,
#  <Feature: scannedLineItemsTotal - scansWithoutRegistration>,
#  <Feature: grandTotal - totalScanTimeInSeconds>,
#  <Feature: quantityModifications - scansWithoutRegistration>,
#  <Feature: totalScanTimeInSeconds - trustLevel>,
#  <Feature: grandTotal - trustLevel>]

# %%
# encode values
fm_encoded, features_encoded = ft.encode_features(feature_matrix,
                                                  features)
fm_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1879 entries, 0 to 1878
# Columns: 112 entries, trustLevel to scansWithoutRegistration - totalScanTimeInSeconds
# dtypes: float64(77), int64(35)
# memory usage: 1.6 MB

# %% [markdown]
# # Correlation Check

# %%
df = pd.read_csv('train.csv', sep='|')
fm_encoded['fraud']=df['fraud']

# %%
#absolute correlation matrix sorted with descending order
corr_abs = abs(fm_encoded.corr())
corr_abs[['fraud']].sort_values(by='fraud',ascending=False)
# Out:
#                                                       fraud
# fraud                                              1.000000
# scannedLineItemsTotal / trustLevel                 0.660235
# totalScanTimeInSeconds / trustLevel                0.437771
# scansWithoutRegistration / trustLevel              0.381772
# scannedLineItemsTotal - trustLevel                 0.354860
# lineItemVoids / trustLevel                         0.352699
# trustLevel                                         0.319765
# grandTotal / trustLevel                            0.309455
# scannedLineItemsTotal * totalScanTimeInSeconds     0.309371
# scannedLineItemsTotal + scansWithoutRegistration   0.308496
# lineItemVoids + scannedLineItemsTotal              0.298617
# scannedLineItemsTotal                              0.298423
# quantityModifications + scannedLineItemsTotal      0.294730
# quantityModifications - scannedLineItemsTotal      0.291151
# scannedLineItemsTotal * scansWithoutRegistration   0.271694
# quantityModifications / trustLevel                 0.270586
# lineItemVoids - scannedLineItemsTotal              0.255936
# scannedLineItemsTotal - scansWithoutRegistration   0.253452
# lineItemVoids * scannedLineItemsTotal              0.246736
# scannedLineItemsTotal + trustLevel                 0.230957
# quantityModifications - trustLevel                 0.227163
# quantityModifications + trustLevel                 0.226903
# scansWithoutRegistration - trustLevel              0.219603
# scannedLineItemsTotal / quantityModifications      0.215562
# grandTotal * trustLevel                            0.198792
# lineItemVoids - trustLevel                         0.197472
# grandTotal * scannedLineItemsTotal                 0.196924
# quantityModifications * scannedLineItemsTotal      0.182353
# trustLevel / quantityModifications                 0.181924
# quantityModifications * trustLevel                 0.176223
# ...                                                     ...
# trustLevel / totalScanTimeInSeconds                0.032576
# grandTotal / quantityModifications                 0.030080
# grandTotal / totalScanTimeInSeconds                0.028873
# quantityModifications / totalScanTimeInSeconds     0.028360
# lineItemVoids / totalScanTimeInSeconds             0.026932
# scannedLineItemsTotal / totalScanTimeInSeconds     0.023085
# scansWithoutRegistration / totalScanTimeInSeconds  0.022587
# grandTotal - trustLevel                            0.020330
# quantityModifications / scansWithoutRegistration   0.018381
# grandTotal + trustLevel                            0.017388
# scansWithoutRegistration / lineItemVoids           0.012135
# totalScanTimeInSeconds / scansWithoutRegistration  0.011404
# quantityModifications / grandTotal                 0.011218
# grandTotal + scansWithoutRegistration              0.009438
# trustLevel / grandTotal                            0.009197
# grandTotal + lineItemVoids                         0.008923
# grandTotal - scansWithoutRegistration              0.006561
# grandTotal - lineItemVoids                         0.006112
# totalScanTimeInSeconds / grandTotal                0.006014
# lineItemVoids / scansWithoutRegistration           0.005331
# grandTotal * quantityModifications                 0.004948
# scansWithoutRegistration / grandTotal              0.003817
# lineItemVoids / grandTotal                         0.003501
# lineItemVoids - scansWithoutRegistration           0.002887
# scannedLineItemsTotal / grandTotal                 0.002763
# grandTotal - quantityModifications                 0.001468
# grandTotal                                         0.001421
# grandTotal + quantityModifications                 0.001369
# quantityModifications                              0.000864
# totalScanTimeInSeconds / lineItemVoids             0.000120
#
# [113 rows x 1 columns]
