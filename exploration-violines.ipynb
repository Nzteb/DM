# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math

# %% [markdown]
# ### Import csv file

# %%
df_train = pd.read_csv('train.csv', sep='|')
df_test = pd.read_csv('test.csv', sep='|')

# %% [markdown]
# ### check that data types are correctly imported

# %%
df_train.dtypes
# Out:
# trustLevel                     int64
# totalScanTimeInSeconds         int64
# grandTotal                   float64
# lineItemVoids                  int64
# scansWithoutRegistration       int64
# quantityModifications          int64
# scannedLineItemsPerSecond    float64
# valuePerSecond               float64
# lineItemVoidsPerPosition     float64
# fraud                          int64
# dtype: object

# %%
df_test.dtypes
# Out:
# trustLevel                     int64
# totalScanTimeInSeconds         int64
# grandTotal                   float64
# lineItemVoids                  int64
# scansWithoutRegistration       int64
# quantityModifications          int64
# scannedLineItemsPerSecond    float64
# valuePerSecond               float64
# lineItemVoidsPerPosition     float64
# dtype: object

# %% [markdown]
# ### check distribution of target variable 'fraud'

# %%
sns.countplot(df_train['fraud'])

# %%
sum(df_train['fraud'] == 1)/len(df_train)
# Out:
# 0.05534858967535923

# %% [markdown]
# - target variable is imabalanced, only 5.53% of the observations are classified as 'fraud'
# - this is in line with the 5% from the task description

# %% [markdown]
# ### create new features
# __scannedLineItemsTotal__
# - scannedLineItemsTotal = scannedLineItemsPerSecond * totalScanTimeInSeconds
# - total number of scanned products

# %%
df_train['scannedLineItemsTotal'] = df_train['scannedLineItemsPerSecond'] * df_train['totalScanTimeInSeconds']
df_test['scannedLineItemsTotal'] = df_test['scannedLineItemsPerSecond'] * df_test['totalScanTimeInSeconds']

# %% [markdown]
# __valuePerLineItem__
# - valuePerLineItem = grandTotal / scannedLineItemsTotal
# - average value per product

# %%
df_train['valuePerLineItem'] = df_train['grandTotal'] / df_train['scannedLineItemsTotal']
df_test['valuePerLineItem'] = df_test['grandTotal'] / df_test['scannedLineItemsTotal']

# %% [markdown]
# __quantityModificationsPerLineItem__
# - quantityModificationsPerLineItem = quantityModifications / scannedLineItemsTotal
# - average number of quantity modifications per product

# %%
df_train['quantityModificationsPerLineItem'] = df_train['quantityModifications'] / df_train['scannedLineItemsTotal']
df_test['quantityModificationsPerLineItem'] = df_test['quantityModifications'] / df_test['scannedLineItemsTotal']

# %% [markdown]
# ### sanity checks
# - lineItemVoids / scannedLineItemsTotal == lineItemVoidsPerPosition

# %%
x = round(df_train['lineItemVoids']/df_train['scannedLineItemsTotal'],10)
y = round(df_train['lineItemVoidsPerPosition'],10)
sum(x == y)/len(x)
# Out:
# 1.0

# %% [markdown]
# ## correlation matrix
# ### standard correlation matrix

# %%
corr = df_train.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_3346601e_5fb8_11e9_b472_037d370ed2c7row0_col0 {
#             background-color:  #b40426;
#         }    #T_3346601e_5fb8_11e9_b472_037d370ed2c7row0_col1 {
#             background-color:  #85a8fc;
#         }    #T_3346601e_5fb8_11e9_b472_037d370ed2c7row0_col2 {
#             background-color:  #516ddb;
#         }    #T_3346601e_5fb8_11e9_b472_037d370ed2c7row0_col3 {
#             background-color:  #3d50c3;
#         }    #T_3346601e_5fb8_11e9_b472_037d370ed2c7row0_col4 {
#             background-color:  #485fd1;
#         }    #T_3346601e_5fb8_11e9_b472_037d370ed2c7row0_col5 {
#             background-color:  #465ecf;
#         }    #T_3346601e_5fb8_11e9_b472_037d370ed2c7row0_col6 {
#             background-color:  #86a9fc;
#         }    #T_3346601e_5fb8_11e9_b472_037d370ed2c7row0_col7 {
#             background-color:  #7a9df8;
#         }    #T_3346601e_5fb8_11e9_b472_037d370ed2c7row0_col8 {
#             background-color:  #afcafc;
#         }    #T_3346601e_5fb8_11e9_b472_037d370ed2c7row0_col9 {
#             background-color:  #3b4cc0;
#         }    #T_3346601e_5fb8_11e9_b472_037d370ed2c7row0_col10 {
#             background-color:  #b2ccfb;
#         }    #T_3346601e_5fb8_11e9_b472_037d370ed2c7row0_col11 {
#             background-color:  #b2ccfb;
#         }    #T_3346601e_5fb8_11e9_b472_037d370ed2c7row0_col12 {
#             background-color:  #adc9fd;
#         }    #T_3346601e_5fb8_11e9_b472_037d370ed2c7row1_col0 {
#             background-color:  #90b2fe;
#         }    #T_3346601e_5fb8_11e9_b472_037d370ed2c7row1_col1 {
#             background-color:  #b40426;
#         }    #T_3346601e_5fb8_11e9_b472_037d370ed2c7row1_col2 {
#             background-color:  #4358cb;
#         }    #T_3346601e_5fb8_11e9_b472_037d370ed2c7row1_col3 {
#             background-color:  #485fd1;
#         }    #T_3346601e_5fb8_11e9_b472_037d370ed2c7row1_col4 {
#             background-color:  #455cce;
#         }    #T_3346601e_5fb8_11e9_b472_037d370ed2c7row1_col5 {
#             background-color:  #4055c8;
#         }    #T_3346601e_5fb8_11e9_b472_037d370ed2c7row1_col6 {
#             background-color:  #3b4cc0;
#         }    #T_3346601e_5fb8_11e9_b472_037d370ed2c7row1_col7 {
#             background-color:  #3b4cc0;
#         }    #T_3346601e_5fb8_11e9_b472_037d370ed2c7row1_col8 {
#             background-color:  #aac7fd;
#         }    #T_3346601e_5fb8_11e9_b472_037d370ed2c7row1_col9 {
#             background-color:  #a7c5fe;
#         }    #T_3346601e_5fb8_11e9_b472_037d370ed2c7row1_col10 {
#             background-color:  #b2ccfb;
#         }    #T_3346601e_5fb8_11e9_b472_037d370ed2c7row1_col11 {
#             background-color:  #adc9fd;
#         }    #T_3346601e_5fb8_11e9_b472_037d370ed2c7row1_col12 {
#             background-color:  #a5c3fe;
#         }    #T_3346601e_5fb8_11e9_b472_037d370ed2c7row2_col0 {
#             background-color:  #97b8ff;
#         }    #T_3346601e_5fb8_11e9_b472_037d370ed2c7row2_col1 {
#             background-color:  #7ea1fa;
#         }    #T_3346601e_5fb8_11e9_b472_037d370ed2c7row2_col2 {
#             background-color:  #b40426;
#         }    #T_3346601e_5fb8_11e9_b472_037d370ed2c7row2_col3 {
#             background-color:  #4358cb;
#         }    #T_3346601e_5fb8_11e9_b472_037d370ed2c7row2_col4 {
#             background-color:  #3b4cc0;
#         }    #T_3346601e_5fb8_11e9_b472_037d370ed2c7row2_col5 {
#             background-color:  #4257c9;
#         }    #T_3346601e_5fb8_11e9_b472_037d370ed2c7row2_col6 {
#             background-color:  #7a9df8;
#         }    #T_3346601e_5fb8_11e9_b472_037d370ed2c7row2_col7 {
#             background-color:  #88abfd;
#         }    #T_3346601e_5fb8_11e9_b472_037d370ed2c7row2_col8 {
#             background-color:  #aac7fd;
#         }    #T_3346601e_5fb8_11e9_b472_037d370ed2c7row2_col9 {
#             background-color:  #8badfd;
#         }    #T_3346601e_5fb8_11e9_b472_037d370ed2c7row2_col10 {
#             background-color:  #afcafc;
#         }    #T_3346601e_5fb8_11e9_b472_037d370ed2c7row2_col11 {
#             background-color:  #ecd3c5;
#         }    #T_3346601e_5fb8_11e9_b472_037d370ed2c7row2_col12 {
#             background-color:  #abc8fd;
#         }    #T_3346601e_5fb8_11e9_b472_037d370ed2c7row3_col0 {
#             background-color:  #85a8fc;
#         }    #T_3346601e_5fb8_11e9_b472_037d370ed2c7row3_col1 {
#             background-color:  #84a7fc;
#         }    #T_3346601e_5fb8_11e9_b472_037d370ed2c7row3_col2 {
#             background-color:  #455cce;
#         }    #T_3346601e_5fb8_11e9_b472_037d370ed2c7row3_col3 {
#             background-color:  #b40426;
#         }    #T_3346601e_5fb8_11e9_b472_037d370ed2c7row3_col4 {
#             background-color:  #3e51c5;
#         }    #T_3346601e_5fb8_11e9_b472_037d370ed2c7row3_col5 {
#             background-color:  #4358cb;
#         }    #T_3346601e_5fb8_11e9_b472_037d370ed2c7row3_col6 {
#             background-color:  #7da0f9;
#         }    #T_3346601e_5fb8_11e9_b472_037d370ed2c7row3_col7 {
#             background-color:  #7396f5;
#         }    #T_3346601e_5fb8_11e9_b472_037d370ed2c7row3_col8 {
#             background-color:  #edd2c3;
#         }    #T_3346601e_5fb8_11e9_b472_037d370ed2c7row3_col9 {
#             background-color:  #9bbcff;
#         }    #T_3346601e_5fb8_11e9_b472_037d370ed2c7row3_col10 {
#             background-color:  #b5cdfa;
#         }    #T_3346601e_5fb8_11e9_b472_037d370ed2c7row3_col11 {
#             background-color:  #abc8fd;
#         }    #T_3346601e_5fb8_11e9_b472_037d370ed2c7row3_col12 {
#             background-color:  #a9c6fd;
#         }    #T_3346601e_5fb8_11e9_b472_037d370ed2c7row4_col0 {
#             background-color:  #8fb1fe;
#         }    #T_3346601e_5fb8_11e9_b472_037d370ed2c7row4_col1 {
#             background-color:  #81a4fb;
#         }    #T_3346601e_5fb8_11e9_b472_037d370ed2c7row4_col2 {
#             background-color:  #3b4cc0;
#         }    #T_3346601e_5fb8_11e9_b472_037d370ed2c7row4_col3 {
#             background-color:  #3d50c3;
#         }    #T_3346601e_5fb8_11e9_b472_037d370ed2c7row4_col4 {
#             background-color:  #b40426;
#         }    #T_3346601e_5fb8_11e9_b472_037d370ed2c7row4_col5 {
#             background-color:  #4a63d3;
#         }    #T_3346601e_5fb8_11e9_b472_037d370ed2c7row4_col6 {
#             background-color:  #779af7;
#         }    #T_3346601e_5fb8_11e9_b472_037d370ed2c7row4_col7 {
#             background-color:  #6c8ff1;
#         }    #T_3346601e_5fb8_11e9_b472_037d370ed2c7row4_col8 {
#             background-color:  #adc9fd;
#         }    #T_3346601e_5fb8_11e9_b472_037d370ed2c7row4_col9 {
#             background-color:  #9ebeff;
#         }    #T_3346601e_5fb8_11e9_b472_037d370ed2c7row4_col10 {
#             background-color:  #aac7fd;
#         }    #T_3346601e_5fb8_11e9_b472_037d370ed2c7row4_col11 {
#             background-color:  #b1cbfc;
#         }    #T_3346601e_5fb8_11e9_b472_037d370ed2c7row4_col12 {
#             background-color:  #adc9fd;
#         }    #T_3346601e_5fb8_11e9_b472_037d370ed2c7row5_col0 {
#             background-color:  #8caffe;
#         }    #T_3346601e_5fb8_11e9_b472_037d370ed2c7row5_col1 {
#             background-color:  #7a9df8;
#         }    #T_3346601e_5fb8_11e9_b472_037d370ed2c7row5_col2 {
#             background-color:  #4055c8;
#         }    #T_3346601e_5fb8_11e9_b472_037d370ed2c7row5_col3 {
#             background-color:  #3f53c6;
#         }    #T_3346601e_5fb8_11e9_b472_037d370ed2c7row5_col4 {
#             background-color:  #4961d2;
#         }    #T_3346601e_5fb8_11e9_b472_037d370ed2c7row5_col5 {
#             background-color:  #b40426;
#         }    #T_3346601e_5fb8_11e9_b472_037d370ed2c7row5_col6 {
#             background-color:  #7a9df8;
#         }    #T_3346601e_5fb8_11e9_b472_037d370ed2c7row5_col7 {
#             background-color:  #7597f6;
#         }    #T_3346601e_5fb8_11e9_b472_037d370ed2c7row5_col8 {
#             background-color:  #b1cbfc;
#         }    #T_3346601e_5fb8_11e9_b472_037d370ed2c7row5_col9 {
#             background-color:  #89acfd;
#         }    #T_3346601e_5fb8_11e9_b472_037d370ed2c7row5_col10 {
#             background-color:  #a9c6fd;
#         }    #T_3346601e_5fb8_11e9_b472_037d370ed2c7row5_col11

# %% [markdown]
# ### absolute correlation between fraud and all other features

# %%
corr_abs = abs(df_train.corr())
corr_abs[['fraud']].style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_357d7e76_5fb8_11e9_b472_037d370ed2c7row0_col0 {
#             background-color:  #a5c3fe;
#         }    #T_357d7e76_5fb8_11e9_b472_037d370ed2c7row1_col0 {
#             background-color:  #5d7ce6;
#         }    #T_357d7e76_5fb8_11e9_b472_037d370ed2c7row2_col0 {
#             background-color:  #3b4cc0;
#         }    #T_357d7e76_5fb8_11e9_b472_037d370ed2c7row3_col0 {
#             background-color:  #4e68d8;
#         }    #T_357d7e76_5fb8_11e9_b472_037d370ed2c7row4_col0 {
#             background-color:  #506bda;
#         }    #T_357d7e76_5fb8_11e9_b472_037d370ed2c7row5_col0 {
#             background-color:  #3b4cc0;
#         }    #T_357d7e76_5fb8_11e9_b472_037d370ed2c7row6_col0 {
#             background-color:  #4055c8;
#         }    #T_357d7e76_5fb8_11e9_b472_037d370ed2c7row7_col0 {
#             background-color:  #4358cb;
#         }    #T_357d7e76_5fb8_11e9_b472_037d370ed2c7row8_col0 {
#             background-color:  #5572df;
#         }    #T_357d7e76_5fb8_11e9_b472_037d370ed2c7row9_col0 {
#             background-color:  #b40426;
#         }    #T_357d7e76_5fb8_11e9_b472_037d370ed2c7row10_col0 {
#             background-color:  #9ebeff;
#         }    #T_357d7e76_5fb8_11e9_b472_037d370ed2c7row11_col0 {
#             background-color:  #5977e3;
#         }    #T_357d7e76_5fb8_11e9_b472_037d370ed2c7row12_col0 {
#             background-color:  #5673e0;
#         }</style>
# <table id="T_357d7e76_5fb8_11e9_b472_037d370ed2c7" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >fraud</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_357d7e76_5fb8_11e9_b472_037d370ed2c7level0_row0" class="row_heading level0 row0" >trustLevel</th>
#         <td id="T_357d7e76_5fb8_11e9_b472_037d370ed2c7row0_col0" class="data row0 col0" >0.319765</td>
#     </tr>    <tr>
#         <th id="T_357d7e76_5fb8_11e9_b472_037d370ed2c7level0_row1" class="row_heading level0 row1" >totalScanTimeInSeconds</th>
#         <td id="T_357d7e76_5fb8_11e9_b472_037d370ed2c7row1_col0" class="data row1 col0" >0.110414</td>
#     </tr>    <tr>
#         <th id="T_357d7e76_5fb8_11e9_b472_037d370ed2c7level0_row2" class="row_heading level0 row2" >grandTotal</th>
#         <td id="T_357d7e76_5fb8_11e9_b472_037d370ed2c7row2_col0" class="data row2 col0" >0.00142089</td>
#     </tr>    <tr>
#         <th id="T_357d7e76_5fb8_11e9_b472_037d370ed2c7level0_row3" class="row_heading level0 row3" >lineItemVoids</th>
#         <td id="T_357d7e76_5fb8_11e9_b472_037d370ed2c7row3_col0" class="data row3 col0" >0.0634963</td>
#     </tr>    <tr>
#         <th id="T_357d7e76_5fb8_11e9_b472_037d370ed2c7level0_row4" class="row_heading level0 row4" >scansWithoutRegistration</th>
#         <td id="T_357d7e76_5fb8_11e9_b472_037d370ed2c7row4_col0" class="data row4 col0" >0.0741225</td>
#     </tr>    <tr>
#         <th id="T_357d7e76_5fb8_11e9_b472_037d370ed2c7level0_row5" class="row_heading level0 row5" >quantityModifications</th>
#         <td id="T_357d7e76_5fb8_11e9_b472_037d370ed2c7row5_col0" class="data row5 col0" >0.000863773</td>
#     </tr>    <tr>
#         <th id="T_357d7e76_5fb8_11e9_b472_037d370ed2c7level0_row6" class="row_heading level0 row6" >scannedLineItemsPerSecond</th>
#         <td id="T_357d7e76_5fb8_11e9_b472_037d370ed2c7row6_col0" class="data row6 col0" >0.0230853</td>
#     </tr>    <tr>
#         <th id="T_357d7e76_5fb8_11e9_b472_037d370ed2c7level0_row7" class="row_heading level0 row7" >valuePerSecond</th>
#         <td id="T_357d7e76_5fb8_11e9_b472_037d370ed2c7row7_col0" class="data row7 col0" >0.0288727</td>
#     </tr>    <tr>
#         <th id="T_357d7e76_5fb8_11e9_b472_037d370ed2c7level0_row8" class="row_heading level0 row8" >lineItemVoidsPerPosition</th>
#         <td id="T_357d7e76_5fb8_11e9_b472_037d370ed2c7row8_col0" class="data row8 col0" >0.0901164</td>
#     </tr>    <tr>
#         <th id="T_357d7e76_5fb8_11e9_b472_037d370ed2c7level0_row9" class="row_heading level0 row9" >fraud</th>
#         <td id="T_357d7e76_5fb8_11e9_b472_037d370ed2c7row9_col0" class="data row9 col0" >1</td>
#     </tr>    <tr>
#         <th id="T_357d7e76_5fb8_11e9_b472_037d370ed2c7level0_row10" class="row_heading level0 row10" >scannedLineItemsTotal</th>
#         <td id="T_357d7e76_5fb8_11e9_b472_037d370ed2c7row10_col0" class="data row10 col0" >0.298423</td>
#     </tr>    <tr>
#         <th id="T_357d7e76_5fb8_11e9_b472_037d370ed2c7level0_row11" class="row_heading level0 row11" >valuePerLineItem</th>
#         <td id="T_357d7e76_5fb8_11e9_b472_037d370ed2c7row11_col0" class="data row11 col0" >0.100765</td>
#     </tr>    <tr>
#         <th id="T_357d7e76_5fb8_11e9_b472_037d370ed2c7level0_row12" class="row_heading level0 row12" >quantityModificationsPerLineItem</th>
#         <td id="T_357d7e76_5fb8_11e9_b472_037d370ed2c7row12_col0" class="data row12 col0" >0.0943931</td>
#     </tr></tbody>
# </table>

# %% [markdown]
# - _trustLevel_ and the new feature _scannedLineItemsTotal_ are quite correlated with the target variable
# - the other two new features _valuePerLineItem_ and _quantitiyModificationsPerLineItem_ have a moderate correlation with the target variable
#   - However, we should be careful, as their correlation might only come from the fact that they are created using _scannedLineItemsTotal_
# - other features that might be interesting based on the correlation are:
#   - _totalScanTimeInseconds_
#   - _lineItemVoids_
#   - _scansWithoutRegistration_
#   - _lineItemVoidsPerPosition_

# %% [markdown]
# ## for each feature compare histograms of fraud and noFraud

# %%
features = df_train.columns[df_train.columns != 'fraud']
numberOfRows = math.ceil(len(features) / 3)

plt.figure(figsize=(20,numberOfRows*4))
labels=['NoFraud','Fraud']
i = 1
for f in features:
    plt.subplot(numberOfRows, 3, i)
    sns.violinplot(x=df_train['fraud'], y=df_train[f])
    #featureNoFraud = df_train[f].loc[df_train['fraud'] == 0]
    #featureFraud = df_train[f].loc[df_train['fraud'] == 1]
    #plt.hist([featureNoFraud,featureFraud], bins='auto',density=True, label=labels)
    #plt.legend()
    plt.xlabel('')
    plt.ylabel('')
    plt.title(f)
    i+=1

# %% [markdown]
# - it is very interesting to see that _fraud_ occurs only in _trustLevel_ 1 and 2
# - additonally _fraud_ only occurs for observations where _scannedLineItemsTotal_ is above 20
# - we should investigate if it makes sense to remove outliers for some features
# - interestingly most of the outliers seem to be non _fraud_ cases

# %% [markdown]
# ### Look again at some features after removing possible outliers

# %%
# Create dictionary of the form (key: [outlier threshold, number of bins])
featuresNoOutlier = {'scannedLineItemsPerSecond': [1,15],
                     'valuePerSecond': [1,15],
                     'lineItemVoidsPerPosition': [3,15],
                     'valuePerLineItem': [20,15],
                     'quantityModificationsPerLineItem': [1,15]}
numberOfRows = math.ceil(len(featuresNoOutlier) / 3)

plt.figure(figsize=(20,numberOfRows*4))
labels=['NoFraud','Fraud']
i = 1
for f, value in featuresNoOutlier.items():
    plt.subplot(numberOfRows, 3, i)
    indicator = df_train[f] < value[0]
    sns.violinplot(x=df_train['fraud'][indicator], y=df_train[f][indicator])
    #featureNoFraud = df_train[f][indicator].loc[df_train['fraud'][indicator] == 0]
    #featureFraud = df_train[f][indicator].loc[df_train['fraud'][indicator] == 1]
    #plt.hist([featureNoFraud,featureFraud], bins=value[1],density=True, label=labels)
    #plt.legend()
    plt.xlabel('')
    plt.ylabel('')
    plt.title(f)
    i+=1

# %% [markdown]
# - _valuePerLineItem_ seems to be lower on average for _fraud_
# - overall, most of the features behave at least a little bit different for _fraud_ and non _fraud_

# %% [markdown]
# ## for each feature compare histograms of train and test

# %%
# create one data frame with test and training set
# add a column('test') that indicates if the observation comes from the test set or not
df_train_tmp = df_train.drop('fraud',axis = 1)
df_train_tmp['test'] = 0
df_test_tmp = df_test
df_test_tmp['test'] = 1
df_merged = df_train_tmp.append(df_test_tmp)

numberOfRows = math.ceil(len(features) / 3)
plt.figure(figsize=(20,numberOfRows*4))
labels=['Train','Test']
i = 1
for f in features:
    plt.subplot(numberOfRows, 3, i)
    sns.violinplot(x=df_merged['test'], y=df_merged[f])
    #plt.hist([df_train[f],df_test[f]], bins='auto',density=True, label=labels)
    #plt.legend()
    plt.xlabel('')
    plt.ylabel('')
    plt.title(f)
    i+=1

# %% [markdown]
# ### Look again at some features after removing possible outliers

# %%
# Create dictionary of the form (key: [outlier threshold, number of bins])
featuresNoOutlier = {'scannedLineItemsPerSecond': [1,15],
                     'valuePerSecond': [1,15],
                     'lineItemVoidsPerPosition': [3,15],
                     'valuePerLineItem': [20,15],
                     'quantityModificationsPerLineItem': [1,15]}
numberOfRows = math.ceil(len(featuresNoOutlier) / 3)

plt.figure(figsize=(20,numberOfRows*4))
labels=['Train','Test']
i = 1
for f, value in featuresNoOutlier.items():
    plt.subplot(numberOfRows, 3, i)
    indicator = df_merged[f] < value[0]
    sns.violinplot(x=df_merged['test'][indicator], y=df_merged[f][indicator])
    #indicatorTrain = df_train[f] < value[0]
    #indicatorTest = df_test[f] < value[0]
    #plt.hist([df_train[f].loc[indicatorTrain],df_test[f].loc[indicatorTest]], bins=value[1],density=True, label=labels)
    #plt.legend()
    plt.xlabel('')
    plt.ylabel('')
    plt.title(f)
    i+=1

# %% [markdown]
# - Distributions of the test set and the training set seem to be similar
